# %%
import torch
import torch.nn as nn
from IPython.display import Image
# !pip install torchview
import torchvision
from torchview import draw_graph

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
model_parameters={}
model_parameters['resnet18'] = ([64,128,256,512],[2,2,2,2],1,False)
model_parameters['resnet34'] = ([64,128,256,512],[3,4,6,3],1,False)
model_parameters['resnet50'] = ([64,128,256,512],[3,4,6,3],4,True)
model_parameters['resnet101'] = ([64,128,256,512],[3,4,23,3],4,True)
model_parameters['resnet152'] = ([64,128,256,512],[3,8,36,3],4,True)


class Bottleneck(nn.Module):

    def __init__(self,in_channels,intermediate_channels,expansion,is_Bottleneck,stride):
        
        """
        Creates a Bottleneck with conv 1x1->3x3->1x1 layers.
        
        Note:
          1. Addition of feature maps occur at just before the final ReLU with the input feature maps
          2. if input size is different from output, select projected mapping or else identity mapping.
          3. if is_Bottleneck=False (3x3->3x3) are used else (1x1->3x3->1x1). Bottleneck is required for resnet-50/101/152
        Args:
            in_channels (int) : input channels to the Bottleneck
            intermediate_channels (int) : number of channels to 3x3 conv 
            expansion (int) : factor by which the input #channels are increased
            stride (int) : stride applied in the 3x3 conv. 2 for first Bottleneck of the block and 1 for remaining

        Attributes:
            Layer consisting of conv->batchnorm->relu

        """

        super(Bottleneck,self).__init__()

        self.expansion = expansion
        self.in_channels = in_channels
        self.intermediate_channels = intermediate_channels
        self.is_Bottleneck = is_Bottleneck
        
        # i.e. if dim(x) == dim(F) => Identity function
        if self.in_channels==self.intermediate_channels*self.expansion:
            self.identity = True
        else:
            self.identity = False
            projection_layer = []
            projection_layer.append(nn.Conv2d(in_channels=self.in_channels, out_channels=self.intermediate_channels*self.expansion, kernel_size=1, stride=stride, padding=0, bias=False ))
            projection_layer.append(nn.BatchNorm2d(self.intermediate_channels*self.expansion))
            # Only conv->BN and no ReLU
            # projection_layer.append(nn.ReLU())
            self.projection = nn.Sequential(*projection_layer)

        # commonly used relu
        self.relu = nn.ReLU()

        # is_Bottleneck = True for all ResNet 50+
        if self.is_Bottleneck:
            # bottleneck
            # 1x1
            self.conv1_1x1 = nn.Conv2d(in_channels=self.in_channels, out_channels=self.intermediate_channels, kernel_size=1, stride=1, padding=0, bias=False )
            self.batchnorm1 = nn.BatchNorm2d(self.intermediate_channels)
            
            # 3x3
            self.conv2_3x3 = nn.Conv2d(in_channels=self.intermediate_channels, out_channels=self.intermediate_channels, kernel_size=3, stride=stride, padding=1, bias=False )
            self.batchnorm2 = nn.BatchNorm2d(self.intermediate_channels)
            
            # 1x1
            self.conv3_1x1 = nn.Conv2d(in_channels=self.intermediate_channels, out_channels=self.intermediate_channels*self.expansion, kernel_size=1, stride=1, padding=0, bias=False )
            self.batchnorm3 = nn.BatchNorm2d( self.intermediate_channels*self.expansion )
        
        else:
            # basicblock
            # 3x3
            self.conv1_3x3 = nn.Conv2d(in_channels=self.in_channels, out_channels=self.intermediate_channels, kernel_size=3, stride=stride, padding=1, bias=False )
            self.batchnorm1 = nn.BatchNorm2d(self.intermediate_channels)
            
            # 3x3
            self.conv2_3x3 = nn.Conv2d(in_channels=self.intermediate_channels, out_channels=self.intermediate_channels, kernel_size=3, stride=1, padding=1, bias=False )
            self.batchnorm2 = nn.BatchNorm2d(self.intermediate_channels)

    def forward(self,x):
        # input stored to be added before the final relu
        in_x = x

        if self.is_Bottleneck:
            # conv1x1->BN->relu
            x = self.relu(self.batchnorm1(self.conv1_1x1(x)))
            
            # conv3x3->BN->relu
            x = self.relu(self.batchnorm2(self.conv2_3x3(x)))
            
            # conv1x1->BN
            x = self.batchnorm3(self.conv3_1x1(x))
        
        else:
            # conv3x3->BN->relu
            x = self.relu(self.batchnorm1(self.conv1_3x3(x)))

            # conv3x3->BN
            x = self.batchnorm2(self.conv2_3x3(x))


        # identity or projected mapping
        if self.identity:
            x += in_x
        else:
            x += self.projection(in_x)

        # final relu
        x = self.relu(x)
        
        return x


# Bottleneck(64*4,64,4,stride=1)

def test_Bottleneck():
    x = torch.randn(1,64,112,112)
    model = Bottleneck(64,64,4,True,2)
    print(model(x).shape)
    del model

test_Bottleneck()
# Out:
# torch.Size([1, 256, 56, 56])

# %%
class ResNet(nn.Module):

    def __init__(self, resnet_variant,in_channels,num_classes):
        """
        Creates the ResNet architecture based on the provided variant. 18/34/50/101 etc.
        Based on the input parameters, define the channels list, repeatition list along with expansion factor(4) and stride(3/1)
        using _make_blocks method, create a sequence of multiple Bottlenecks
        Average Pool at the end before the FC layer 

        Args:
            resnet_variant (list) : eg. [[64,128,256,512],[3,4,6,3],4,True]
            in_channels (int) : image channels (3)
            num_classes (int) : output #classes 

        Attributes:
            Layer consisting of conv->batchnorm->relu

        """
        super(ResNet,self).__init__()
        self.channels_list = resnet_variant[0]
        self.repeatition_list = resnet_variant[1]
        self.expansion = resnet_variant[2]
        self.is_Bottleneck = resnet_variant[3]

        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=64, kernel_size=7, stride=2, padding=3, bias=False )
        self.batchnorm1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU()

        self.maxpool = nn.MaxPool2d(kernel_size=3,stride=2,padding=1)

        self.block1 = self._make_blocks( 64 , self.channels_list[0], self.repeatition_list[0], self.expansion, self.is_Bottleneck, stride=1 )
        self.block2 = self._make_blocks( self.channels_list[0]*self.expansion , self.channels_list[1], self.repeatition_list[1], self.expansion, self.is_Bottleneck, stride=2 )
        self.block3 = self._make_blocks( self.channels_list[1]*self.expansion , self.channels_list[2], self.repeatition_list[2], self.expansion, self.is_Bottleneck, stride=2 )
        self.block4 = self._make_blocks( self.channels_list[2]*self.expansion , self.channels_list[3], self.repeatition_list[3], self.expansion, self.is_Bottleneck, stride=2 )

        self.average_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Linear( self.channels_list[3]*self.expansion , num_classes)



    def forward(self,x):
        x = self.relu(self.batchnorm1(self.conv1(x)))
        x = self.maxpool(x)
        
        x = self.block1(x)
        
        x = self.block2(x)
        
        x = self.block3(x)
        
        x = self.block4(x)
        
        x = self.average_pool(x)

        x = torch.flatten(x, start_dim=1)
        x = self.fc1(x)
        
        return x

    def _make_blocks(self,in_channels,intermediate_channels,num_repeat, expansion, is_Bottleneck, stride):
        
        """
        Args:
            in_channels : #channels of the Bottleneck input
            intermediate_channels : #channels of the 3x3 in the Bottleneck
            num_repeat : #Bottlenecks in the block
            expansion : factor by which intermediate_channels are multiplied to create the output channels
            is_Bottleneck : status if Bottleneck in required
            stride : stride to be used in the first Bottleneck conv 3x3

        Attributes:
            Sequence of Bottleneck layers

        """
        layers = [] 

        layers.append(Bottleneck(in_channels,intermediate_channels,expansion,is_Bottleneck,stride=stride))
        for num in range(1,num_repeat):
            layers.append(Bottleneck(intermediate_channels*expansion,intermediate_channels,expansion,is_Bottleneck,stride=1))

        return nn.Sequential(*layers)


def test_ResNet(params):
    model = ResNet( params , in_channels=3, num_classes=1000)
    x = torch.randn(1,3,224,224)
    output = model(x)
    print(output.shape)
    return model

architecture = 'resnet50'
model = test_ResNet(model_parameters[architecture])
# Out:
# torch.Size([1, 1000])

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import matplotlib.pyplot as plt
from tqdm import tqdm

_ = torch.manual_seed(0)

transform = transforms.Compose([transforms.ToTensor() ,

transforms.Normalize((0.1307,),(0.3081,))

])




mnist_trainset = datasets.MNIST(root='./data', train=True, download=False, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=False, transform=transform)

train_loader = torch.utils.data.DataLoader(mnist_trainset, batch_size=10, shuffle=True)
test_loader = torch.utils.data.DataLoader(mnist_testset, batch_size=10, shuffle=False)


# model = SimplifiedVGG16(num_classes=10).to(device)


num_classes = 10
num_epochs = 1
batch_size = 10
learning_rate = 0.005

# model =.to(device)

model = ResNet( model_parameters['resnet50'] , in_channels=1, num_classes=10).to(device)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay = 0.005, momentum = 0.9)  


# Train the model
total_step = len(train_loader)

total_step = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # Move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            
    # Validation
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            del images, labels, outputs
    
        print('Accuracy of the network on the {} validation images: {} %'.format(5000, 100 * correct / total))
# Out:
# Epoch [1/1], Step [6000/6000], Loss: 0.5794
# Accuracy of the network on the 5000 validation images: 94.26 %

# %% [markdown]
# # lets make a copy of original weights

# %%
original_weights = {}

for name , param in model.named_parameters():

    original_weights[name] = param.clone().detach()


print(original_weights)
# Out:
# {'conv1.weight': tensor([[[[ 1.5971e-01,  2.3322e-01,  2.1765e-01,  ..., -1.7124e-03,
#             1.7205e-01,  3.2256e-02],
#           [ 8.3770e-02,  1.9675e-01,  2.7954e-01,  ..., -8.1308e-02,
#            -8.2088e-02, -6.3201e-02],
#           [-8.3370e-02,  1.8852e-01,  2.5028e-01,  ..., -1.5003e-01,
#            -1.6160e-01, -4.5111e-02],
#           ...,
#           [-9.3456e-03, -4.2822e-02,  8.6994e-02,  ...,  2.5766e-01,
#             2.1900e-01,  1.1620e-01],
#           [-1.3293e-01, -1.7470e-01,  6.7129e-02,  ...,  3.4651e-01,
#             1.8532e-01,  1.5070e-01],
#           [-1.1327e-01, -3.2232e-02, -1.1343e-03,  ..., -7.6857e-03,
#             1.4115e-02,  1.3369e-01]]],
#
#
#         [[[-8.3469e-02,  1.5050e-02,  1.5197e-01,  ...,  1.1746e-01,
#             2.3503e-01,  9.4007e-02],
#           [ 4.1660e-02,  7.9188e-02,  1.0423e-01,  ...,  1.4117e-01,
#             1.9122e-01,  2.2379e-01],
#             5.9101e-02, -2.6911e-02],
#           [-1.4300e-01, -5.4386e-02, -7.2657e-02,  ..., -6.7871e-02,
#             1.2781e-02,  5.8196e-02],
#           [-1.4751e-01, -1.1846e-01, -9.3551e-02,  ..., -1.1864e-01,
#            -9.6897e-02, -2.0508e-02],
#           ...,
#           [-2.6603e-01, -3.1031e-01, -2.7193e-01,  ..., -3.3367e-01,
#            -2.4559e-01, -3.4343e-01],
#           [-2.0373e-01, -1.5158e-01, -6.2783e-02,  ..., -2.3401e-01,
#            -2.4642e-01, -3.5024e-01],
#           [-1.1427e-01, -8.4645e-03, -8.7242e-02,  ..., -3.6170e-01,
#            -3.3213e-01, -1.7127e-01]]]], device='cuda:0'), 'batchnorm1.weight': tensor([ 0.5880, -0.2922,  0.2719,  0.3269,  0.1312,  0.1876,  0.2380,  0.1464,
#          0.4744,  0.2635,  0.3916,  0.1669, -0.4848,  0.2744,  0.2414,  0.0641,
#          0.6305,  0.1679,  0.3147,  0.1732,  0.2116,  0.5352, -0.2576,  0.2181,
#          0.1975,  0.1935,  0.4898,  0.4942,  0.1949,  0.2729,  0.3199,  0.8411,
#          0.4861,  0.2235,  0.3548,  0.1400,  0.1707,  0.5166,  0.1703,  0.1033,
#          0.1854,  0.3863,  0.2012, -0.1262,  0.5404,  0.1546,  0.2148,  0.4747,
#          0.0978,  0.0768,  0.3889,  0.3235,  0.0154,  0.5414,  0.1932,  0.0799,
#          0.0197,  0.0556,  0.2477,  0.0113,  0.3294,  0.2756,  0.2318,  0.2199],
#        device='cuda:0'), 'batchnorm1.bias': tensor([ 0.0109,  0.0033,  0.0750,  0.0380,  0.0467,  0.0057, -0.0948,  0.0029,
#          0.1125, -0.0992,  0.0735, -0.0410,  0.0265, -0.1523, -0.0566,  0.0348,
#         -0.0363, -0.1282,  0.0008, -0.0004,  0.0776, -0.0345, -0.0412,  0.0563,
#         -0.0643, -0.1168, -0.1041, -0.0289, -0.0655, -0.0476,  0.0765, -0.0199,
#          0.1094, -0.1181, -0.1413,  0.0221, -0.0120, -0.0631,  0.0320, -0.0019,
#         -0.0556, -0.0751,  0.0186, -0.0426, -0.1678,  0.0803, -0.0369,  0.0827,
#         -0.0686, -0.0667,  0.0176,  0.1222, -0.0879,  0.0505, -0.0799,  0.0004,
#         -0.0883, -0.0170, -0.0576, -0.0604, -0.0414,  0.0189,  0.0142, -0.0057],
#        device='cuda:0'), 'block1.0.projection.0.weight': tensor([[[[-0.0717]],
#
#          [[-0.0150]],
#
#          [[ 0.0451]],
#
#          ...,
#
#          [[-0.0146]],
#
#          [[ 0.0091]],
#
#          [[-0.0350]]],
#
#
#         [[[-0.0213]],
#
#          [[-0.0192]],
#
#          [[-0.0406]],
#
#          ...,
#
#          [[-0.0160]],
#
#          [[-0.0305]],
#
#          [[-0.0761]]],
#
#
#         [[[ 0.0159]],
#
#          [[ 0.0423]],
#
#          [[ 0.0236]],
#
#          ...,
#
#          [[-0.0178]],
#
#          [[ 0.0454]],
#
#          [[ 0.0015]]],
#
#
#         ...,
#
#
#         [[[ 0.0327]],
#
#          [[ 0.0556]],
#
#          [[ 0.0070]],
#
#          ...,
#
#          [[ 0.0450]],
#
#          [[-0.0285]],
#
#          [[-0.0035]]],
#
#
#         [[[ 0.0782]],
#
#          [[ 0.0429]],
#
#          [[-0.1019]],
#
#          ...,
#
#          [[ 0.0621]],
#
#          [[ 0.0397]],
#
#          [[ 0.0174]]],
#
#
#         [[[ 0.1346]],
#
#          [[-0.0801]],
#
#          [[-0.0766]],
#
#          ...,
#
#          [[-0.0747]],
#
#          [[ 0.0642]],
#
#          [[ 0.0377]]]], device='cuda:0'), 'block1.0.projection.1.weight': tensor([0.3667, 0.1820, 0.2071, 0.2716, 0.2267, 0.2335, 0.2091, 0.2589, 0.3166,
#         0.2393, 0.2737, 0.2286, 0.2376, 0.3761, 0.2518, 0.2387, 0.2394, 0.1746,
#         0.2869, 0.2257, 0.2001, 0.2150, 0.2158, 0.2293, 0.2682, 0.2571, 0.2109,
#         0.2509, 0.2295, 0.3320, 0.3244, 0.1762, 0.2580, 0.2546, 0.2825, 0.2234,
#         0.2227, 0.1804, 0.3831, 0.2269, 0.1856, 0.2375, 0.1953, 0.2766, 0.1963,
#         0.3582, 0.2289, 0.2687, 0.2309, 0.2566, 0.1543, 0.2442, 0.2556, 0.2354,
#         0.3271, 0.2296, 0.2040, 0.2791, 0.1957, 0.2067, 0.2299, 0.2379, 0.2838,
#         0.2668, 0.2625, 0.3094, 0.2338, 0.2762, 0.2031, 0.1807, 0.2526, 0.2319,
#         0.3715, 0.1776, 0.3171, 0.3202, 0.2722, 0.2442, 0.2282, 0.2161, 0.2466,
#         0.2391, 0.2762, 0.2322, 0.3621, 0.2814, 0.3602, 0.2052, 0.2331, 0.1989,
#         0.2849, 0.2295, 0.3328, 0.2910, 0.2213, 0.3335, 0.2899, 0.2899, 0.2245,
#         0.1444, 0.2479, 0.2318, 0.2303, 0.2508, 0.2367, 0.2363, 0.2392, 0.1902,
#         0.2519, 0.2159, 0.2337, 0.2349, 0.3241, 0.2242, 0.3040, 0.2324, 0.2661,
#         0.2543, 0.2537, 0.2467, 0.2364, 0.2407, 0.1587, 0.1631, 0.3065, 0.2100,
#         0.2826, 0.1937, 0.2274, 0.3026, 0.2366, 0.3098, 0.2442, 0.3705, 0.2308,
#         0.1784, 0.2590, 0.1901, 0.2731, 0.2195, 0.2183, 0.1904, 0.2685, 0.1466,
#         0.2223, 0.2761, 0.2612, 0.2967, 0.2357, 0.2705, 0.1976, 0.2483, 0.3285,
#         0.2105, 0.2532, 0.2373, 0.4016, 0.2865, 0.3365, 0.3005, 0.2389, 0.2512,
#         0.3906, 0.2026, 0.2738, 0.2246, 0.2725, 0.2239, 0.2187, 0.4106, 0.2612,
#         0.2532, 0.2708, 0.2125, 0.2643, 0.2999, 0.2847, 0.2362, 0.3080, 0.2019,
#         0.2125, 0.3118, 0.2248, 0.2866, 0.2666, 0.2573, 0.2087, 0.2538, 0.3091,
#
#          [[-0.0279]]],
#
#
#         [[[-0.0754]],
#
#          [[ 0.0207]],
#
#          [[ 0.0387]],
#
#          ...,
#
#          [[ 0.1531]],
#
#          [[ 0.1816]],
#
#          [[-0.0304]]],
#
#
#         ...,
#
#
#         [[[-0.1053]],
#
#          [[ 0.0777]],
#
#          [[ 0.1171]],
#
#          ...,
#
#          [[ 0.0455]],
#
#          [[ 0.1605]],
#
#          [[ 0.0605]]],
#
#
#         [[[-0.0111]],
#
#          [[-0.1730]],
#
#          [[-0.0454]],
#
#          ...,
#
#          [[-0.0377]],
#
#          [[-0.0303]],
#
#          [[ 0.0214]]],
#
#
#         [[[ 0.2968]],
#
#          [[-0.0721]],
#
#          [[-0.1319]],
#
#          ...,
#
#          [[-0.0895]],
#
#          [[ 0.0232]],
#
#          [[ 0.0395]]]], device='cuda:0'), 'block1.0.batchnorm1.weight': tensor([ 0.2065,  0.2364,  0.4317,  0.2769,  0.2909,  0.2321,  0.2446,  0.3410,
#          0.0281,  0.2144,  0.4601,  0.1726,  0.1398,  0.2854,  0.2174,  0.1609,
#          0.3625,  0.1012,  0.0764,  0.1802,  0.2042,  0.2367,  0.0444,  0.2436,
#          0.2075,  0.0435,  0.1793,  0.2004,  0.2124,  0.2918,  0.3279,  0.0145,
#          0.2016,  0.6708,  0.0205,  0.4787,  0.3423,  0.2201,  0.2379,  0.0675,
#          0.2341,  0.2022,  0.3521,  0.3559,  0.0189,  0.2824,  0.0116,  0.0229,
#          0.2357,  0.3468,  0.2975,  0.3057,  0.2433, -0.0039,  0.2397,  0.1386,
#          0.2170,  0.2362,  0.3123,  0.1226,  0.2396,  0.2473,  0.3050,  0.1328],
#        device='cuda:0'), 'block1.0.batchnorm1.bias': tensor([ 3.1498e-02, -1.3305e-02,  1.0148e-01,  1.0246e-01,  2.2321e-01,
#          1.9473e-02, -2.8766e-02,  3.7046e-02, -1.0719e-01,  4.0704e-02,
#         -2.8645e-01, -9.1314e-02,  5.0853e-02, -6.8212e-03,  4.3507e-03,
#         -5.8451e-02,  1.4856e-01,  2.0863e-01,  7.7145e-02,  2.3366e-01,
#         -6.4443e-02,  9.2350e-03, -1.4379e-01, -1.2427e-01,  2.9398e-03,
#         -1.4159e-01, -4.7401e-02,  1.9159e-02, -7.5910e-02,  2.2788e-03,
#          1.5624e-01, -5.1882e-02, -5.2988e-02,  4.1844e-01, -8.9012e-02,
#          3.2810e-02,  1.7094e-01, -5.8191e-02,  2.1235e-02,  1.3660e-01,
#          1.6650e-02,  9.6036e-02,  1.2756e-01, -2.4405e-02, -6.6437e-02,
#          1.5603e-01, -6.1370e-02, -1.1586e-01,  2.1240e-02, -3.7496e-02,
#          6.1164e-02,  9.6436e-02,  1.3098e-01, -1.2507e-01,  1.7891e-02,
#          1.6449e-01,  5.3792e-02, -3.8505e-04,  2.4214e-01, -1.2489e-02,
#         -1.8683e-02,  7.3684e-02, -2.1888e-01,  8.8739e-02], device='cuda:0'), 'block1.0.conv2_3x3.weight': tensor([[[[-0.0107,  0.0326, -0.0869],
#           [-0.0320,  0.0434, -0.0459],
#           [-0.0088, -0.0078, -0.0583]],
#
#          [[ 0.0795, -0.0495, -0.0984],
#           [ 0.0579,  0.0156,  0.0604],
#           [-0.0536, -0.0174, -0.0314]],
#
#          [[ 0.0404, -0.0701, -0.0327],
#           [ 0.1160, -0.0267,  0.0285],
#           [ 0.0200, -0.0724, -0.0851]],
#
#          ...,
#
#          [[-0.0210, -0.0528, -0.0583],
#           [ 0.0890, -0.0366, -0.0156],
#           [-0.0002, -0.0738, -0.0560]],
#
#          [[-0.0219,  0.0715, -0.0035],
#           [-0.0622,  0.2137,  0.1074],
#           [-0.1359,  0.1154,  0.0183]],
#
#          [[-0.0283,  0.0629,  0.1178],
#           [-0.0671, -0.1343, -0.0151],
#           [-0.1646, -0.2373, -0.0845]]],
#
#
#         [[[-0.0423, -0.0632, -0.0276],
#           [-0.0248,  0.0081, -0.0158],
#           [ 0.0048, -0.0688, -0.0554]],
#
#          [[-0.0130, -0.0581, -0.0695],
#           [ 0.0251, -0.0091, -0.0036],
#           [ 0.0107,  0.0196, -0.0145]],
#
#          [[ 0.0005, -0.0071, -0.0115],
#           [ 0.0411, -0.0023,  0.0049],
#           [-0.0013,  0.0290,  0.0169]],
#
#          ...,
#
#          [[-0.0144, -0.0874, -0.0536],
#           [-0.0004, -0.0467, -0.0457],
#           [ 0.0537,  0.0137,  0.0060]],
#
#          [[ 0.0485,  0.1864,  0.1562],
#           [-0.0402, -0.0073,  0.1221],
#           [ 0.0314,  0.0232,  0.0189]],
#
#          [[ 0.0532,  0.0285, -0.0468],
#           [ 0.0341,  0.0111, -0.0576],
#           [-0.0104,  0.0065, -0.0508]]],
#
#
#         [[[ 0.0158,  0.0730,  0.0634],
#           [ 0.0040,  0.0217, -0.0078],
#           [ 0.0271,  0.0075, -0.0404]],
#
#          [[ 0.0280,  0.0660,  0.0357],
#           [ 0.0030,  0.0050, -0.0606],
#           [ 0.0483,  0.0529,  0.0238]],
#
#          [[ 0.0725,  0.0748,  0.0400],
#           [ 0.0095,  0.0541, -0.1082],
#           [ 0.0846,  0.0198, -0.0606]],
#
#          ...,
#
#          [[ 0.0183,  0.0203, -0.0004],
#           [-0.0457,  0.0403,  0.0248],
#           [ 0.0460,  0.0334, -0.0495]],
#
#          [[-0.0104, -0.0256, -0.1152],
#           [-0.0568, -0.0490, -0.0096],
#           [-0.0599,  0.0392,  0.1851]],
#
#          [[ 0.0044,  0.0574,  0.0634],
#           [ 0.0776,  0.0921, -0.0052],
#           [ 0.0718,  0.0436, -0.0244]]],
#
#
#         ...,
#
#
#         [[[-0.0052, -0.0071,  0.0207],
#           [-0.0032, -0.0014,  0.0081],
#           [-0.0025,  0.0034, -0.0049]],
#
#          [[ 0.0121,  0.0244, -0.0087],
#           [-0.0013,  0.0434,  0.0640],
#           [ 0.0182,  0.0654,  0.0393]],
#
#          [[ 0.0033,  0.0526, -0.0047],
#           [ 0.0433,  0.0708,  0.0058],
#           [ 0.0296,  0.0926, -0.0027]],
#
#          ...,
#
#          [[-0.0297, -0.0181, -0.0441],
#           [ 0.0156,  0.0676,  0.0276],
#           [ 0.0156,  0.0673,  0.0226]],
#
#          [[-0.0290, -0.0459, -0.0167],
#           [-0.0504, -0.0633,  0.0083],
#           [-0.0317, -0.0402,  0.0231]],
#
#          [[-0.0536,  0.0371,  0.0065],
#           [-0.0369, -0.0260,  0.0109],
#           [ 0.0577,  0.0746, -0.0700]]],
#
#
#         [[[ 0.0257,  0.0379, -0.0097],
#           [-0.0389,  0.0122,  0.0870],
#           [-0.1425,  0.0367,  0.0280]],
#
#          [[-0.0568,  0.0572,  0.0772],
#           [-0.0598,  0.0640,  0.0607],
#           [-0.0309,  0.0602,  0.0436]],
#
#          [[-0.0353,  0.0895,  0.0742],
#           [-0.0494,  0.0672,  0.0416],
#           [-0.0030,  0.0462,  0.0886]],
#
#          ...,
#
#          [[-0.0611,  0.0295,  0.0071],
#           [-0.0651,  0.0409, -0.0060],
#           [-0.0456,  0.0196,  0.0813]],
#
#          [[ 0.0422,  0.0374,  0.0011],
#           [-0.0469, -0.0199, -0.0253],
#           [-0.1201, -0.0579, -0.1237]],
#
#          [[ 0.0335,  0.1246, -0.0298],
#           [-0.0974, -0.0421, -0.0789],
#           [-0.1584, -0.1726, -0.1145]]],
#
#
#         [[[-0.0072, -0.0107,  0.0685],
#           [-0.0863, -0.1242, -0.0665],
#           [-0.0284,  0.0068,  0.0193]],
#
#          [[-0.0376,  0.0066,  0.1314],
#           [-0.0984, -0.0767,  0.0261],
#           [-0.0999, -0.0846, -0.0606]],
#
#          [[-0.0578, -0.0079,  0.1122],
#           [-0.1117, -0.1538,  0.0011],
#           [-0.0531, -0.0931, -0.0242]],
#
#          ...,
#
#          [[-0.0035,  0.0383,  0.0692],
#           [-0.0472, -0.0353,  0.0328],
#           [-0.0614, -0.0603, -0.0432]],
#
#          [[-0.0219,  0.0433, -0.0546],
#           [ 0.0639,  0.0876, -0.1390],
#           [ 0.0672, -0.0390,  0.0199]],
#
#          [[ 0.0694, -0.0023, -0.0817],
#           [-0.0216,  0.0031,  0.0651],
#           [ 0.0695,  0.1429,  0.2279]]]], device='cuda:0'), 'block1.0.batchnorm2.weight': tensor([ 0.2043,  0.0087,  0.2057,  0.2401,  0.2256, -0.0631,  0.3898,  0.2836,
#          0.1982,  0.2101,  0.2298,  0.1380,  0.2339,  0.3334,  0.1917,  0.2154,
#          0.3139,  0.1896,  0.1838,  0.2075,  0.2640,  0.2322,  0.2733,  0.1687,
#          0.2754,  0.3657,  0.2903,  0.2493,  0.1680,  0.4288,  0.2786,  0.2537,
#          0.3237,  0.1606,  0.2764,  0.1984,  0.2211,  0.2609,  0.4567,  0.2745,
#          0.1472,  0.1828,  0.6485,  0.2796,  0.2419,  0.2886,  0.1794,  0.1629,
#          0.1907,  0.2491,  0.2051,  0.2477,  0.2266,  0.0858,  0.1909,  0.1718,
#          0.1184,  0.2265,  0.3028,  0.4255,  0.1528,  0.1692,  0.1905,  0.1717],
#        device='cuda:0'), 'block1.0.batchnorm2.bias': tensor([-0.0732, -0.0596,  0.0320, -0.0015, -0.0902, -0.2312, -0.0905,  0.1277,
#         -0.0027, -0.0135,  0.0176,  0.0004, -0.0423, -0.0339, -0.0492, -0.0538,
#         -0.0271,  0.0349, -0.0352, -0.0589, -0.0885, -0.0647,  0.0209, -0.0278,
#          0.0072,  0.0100,  0.0384, -0.0013,  0.0590,  0.0348, -0.0203, -0.0201,
#          0.0860,  0.0334,  0.1474, -0.0879,  0.1644, -0.0162,  0.0174, -0.0865,
#          0.0374, -0.0873,  0.0920, -0.0147, -0.0192,  0.0020, -0.0530, -0.0942,
#         -0.0014, -0.1243, -0.0631, -0.0092, -0.1386, -0.0767, -0.0212, -0.0314,
#         -0.1324, -0.0623,  0.0260, -0.1036,  0.0370,  0.0136,  0.0528, -0.0534],
#        device='cuda:0'), 'block1.0.conv3_1x1.weight': tensor([[[[ 1.3272e-02]],
#
#          [[-2.3018e-02]],
#
#          [[ 5.3154e-02]],
#
#          ...,
#
#          [[ 2.7196e-03]],
#
#          [[-1.5392e-02]],
#
#          [[ 6.2985e-04]]],
#
#
#         [[[-7.9747e-02]],
#
#          [[-7.6082e-03]],
#
#          [[ 4.6158e-02]],
#
#          ...,
#
#          [[-6.9344e-03]],
#
#          [[-1.4125e-02]],
#
#          [[ 3.5130e-02]]],
#
#
#         [[[ 4.5139e-03]],
#
#          [[-1.5881e-02]],
#
#          [[-7.7124e-03]],
#
#          ...,
#
#          [[ 7.0727e-05]],
#
#          [[-6.0523e-02]],
#
#          [[-9.8066e-03]]],
#
#
#         ...,
#
#
#         [[[-5.0583e-02]],
#
#          [[ 8.3254e-02]],
#
#          [[-2.3129e-02]],
#
#          ...,
#
#          [[-5.0348e-02]],
#
#          [[-1.5277e-02]],
#
#          [[-4.8197e-02]]],
#
#
#         [[[ 2.1299e-02]],
#
#          [[-1.6311e-03]],
#
#          [[-9.7050e-02]],
#
#          ...,
#
#          [[ 2.9043e-02]],
#
#          [[ 6.5502e-02]],
#
#          [[-7.6543e-02]]],
#
#
#         [[[ 2.9618e-02]],
#
#          [[-8.7786e-03]],
#
#          [[ 1.8025e-02]],
#
#          ...,
#
#          [[ 6.5604e-02]],
#
#          [[-2.6395e-03]],
#
#          [[ 9.9655e-03]]]], device='cuda:0'), 'block1.0.batchnorm3.weight': tensor([0.2593, 0.2068, 0.2550, 0.2382, 0.2163, 0.2599, 0.1880, 0.2706, 0.2426,
#         0.2343, 0.2700, 0.1996, 0.2443, 0.1557, 0.2131, 0.1577, 0.2104, 0.3297,
#         0.1972, 0.2414, 0.2093, 0.2003, 0.1990, 0.2356, 0.2158, 0.2218, 0.2494,
#         0.2635, 0.2441, 0.2187, 0.2656, 0.1940, 0.2573, 0.2309, 0.1986, 0.2061,
#         0.2254, 0.1763, 0.1779, 0.2437, 0.2538, 0.2215, 0.1318, 0.2451, 0.2047,
#         0.2971, 0.2015, 0.2010, 0.2072, 0.1941, 0.2986, 0.2187, 0.2105, 0.1839,
#          1.2635e-02, -2.7378e-02,  4.2213e-02,  2.4190e-03,  9.6098e-03,
#          2.6829e-02, -2.8350e-02,  4.7191e-03,  1.4850e-02,  2.7887e-02,
#         -1.0848e-02, -2.1499e-02,  5.7403e-03,  2.2616e-03, -2.0817e-02,
#         -4.5591e-02,  1.2596e-02,  9.6453e-03, -3.8538e-04,  3.5770e-02,
#          3.9320e-03,  6.5288e-02,  8.5080e-02, -7.8569e-03,  5.0343e-02,
#         -2.5633e-02,  2.6747e-03, -2.2405e-03, -3.1483e-02, -2.0455e-03,
#         -2.4052e-02,  4.6375e-02,  6.0860e-02, -7.9787e-03, -5.3533e-02,
#          5.2892e-02,  3.1739e-02, -2.5965e-02,  4.9337e-03, -1.8175e-02,
#         -2.6961e-02,  3.5115e-02,  1.6113e-02,  3.2771e-03, -1.6941e-02,
#         -2.3483e-02,  4.8446e-02,  3.8352e-02, -2.7490e-02,  2.0678e-02,
#         -1.8751e-02,  6.9549e-03, -2.3841e-02,  3.2761e-03,  5.6810e-02,
#          2.5485e-02,  2.0601e-02,  1.9999e-02, -3.3696e-02,  3.7057e-03,
#         -2.7361e-02,  4.8557e-03,  3.1579e-02, -1.9198e-02,  9.6179e-02,
#          4.5556e-02], device='cuda:0'), 'block1.1.conv1_1x1.weight': tensor([[[[ 0.0207]],
#
#          [[-0.0520]],
#
#          [[ 0.0822]],
#
#          ...,
#
#          [[ 0.0671]],
#
#          [[ 0.0045]],
#
#          [[-0.0529]]],
#
#
#         [[[ 0.0093]],
#
#          [[-0.0265]],
#
#          [[ 0.0999]],
#
#          ...,
#
#          [[ 0.0464]],
#
#          [[ 0.0634]],
#
#          [[ 0.0390]]],
#
#
#         [[[ 0.0019]],
#
#          [[-0.0333]],
#
#          [[ 0.0441]],
#
#          ...,
#
#          [[ 0.1189]],
#
#          [[ 0.0790]],
#
#          [[ 0.2059]]],
#
#
#         ...,
#
#
#         [[[ 0.0182]],
#
#          [[-0.0069]],
#
#          [[ 0.1470]],
#
#          ...,
#
#          [[-0.0035]],
#
#          [[-0.0003]],
#
#          [[-0.0082]]],
#
#
#         [[[ 0.0868]],
#
#          [[ 0.0531]],
#
#          [[-0.0237]],
#
#          ...,
#
#          [[-0.0509]],
#
#          [[-0.0477]],
#
#          [[ 0.0196]]],
#
#
#         [[[ 0.0786]],
#
#          [[-0.0207]],
#
#          [[-0.0030]],
#
#          ...,
#
#          [[ 0.0283]],
#
#          [[-0.0866]],
#
#          [[ 0.0056]]]], device='cuda:0'), 'block1.1.batchnorm1.weight': tensor([0.1658, 0.3271, 0.2674, 0.1649, 0.1628, 0.1975, 0.1874, 0.2904, 0.2563,
#         0.3952, 0.1712, 0.1687, 0.2105, 0.1580, 0.2677, 0.2032, 0.2564, 0.3097,
#         0.3332, 0.2222, 0.0083, 0.2189, 0.2426, 0.2311, 0.1559, 0.1499, 0.3198,
#         0.5197, 0.2318, 0.1960, 0.1835, 0.2249, 0.2940, 0.2671, 0.1840, 0.2160,
#         0.1287, 0.2538, 0.2436, 0.3894, 0.3801, 0.2782, 0.2848, 0.3579, 0.2559,
#         0.1741], device='cuda:0'), 'block1.1.batchnorm2.bias': tensor([-0.0493,  0.0602,  0.0574, -0.0764,  0.0390, -0.0170,  0.0815,  0.0390,
#          0.0659, -0.0590, -0.0810,  0.0815, -0.0279,  0.0873, -0.0456,  0.0515,
#          0.0025,  0.0075, -0.0300, -0.0215,  0.0382,  0.0924,  0.0617, -0.0203,
#         -0.1168, -0.0220, -0.1563,  0.0842, -0.0235,  0.0036, -0.0083, -0.0365,
#          0.1616,  0.0481,  0.0398, -0.1174,  0.0189, -0.0206, -0.0303,  0.3178,
#         -0.0169, -0.0214,  0.0632, -0.0056, -0.0639,  0.1474,  0.0863,  0.0319,
#         -0.0133, -0.0231, -0.0420,  0.0004, -0.0305,  0.0432,  0.0733, -0.0228,
#         -0.0277, -0.0224,  0.0504,  0.0436, -0.0292,  0.0664,  0.0647,  0.0494],
#        device='cuda:0'), 'block1.1.conv3_1x1.weight': tensor([[[[ 0.0180]],
#
#          [[-0.0269]],
#
#          [[-0.0102]],
#
#          ...,
#
#          [[-0.0435]],
#
#          [[ 0.0207]],
#
#          [[ 0.0014]]],
#
#
#         [[[ 0.0225]],
#
#          [[ 0.0430]],
#
#          [[ 0.0118]],
#
#          ...,
#
#          [[-0.0012]],
#
#          [[ 0.0382]],
#
#          [[ 0.0578]]],
#
#
#         [[[ 0.0218]],
#
#          [[ 0.0471]],
#
#          [[ 0.0359]],
#
#          ...,
#
#          [[-0.0926]],
#
#          [[ 0.0145]],
#
#          [[-0.0647]]],
#
#
#         ...,
#
#
#         [[[-0.0289]],
#
#          [[-0.0213]],
#
#          [[-0.0341]],
#
#          ...,
#
#          [[-0.0034]],
#
#          [[-0.0688]],
#
#          [[-0.0059]]],
#
#
#         [[[-0.0612]],
#
#          [[-0.0351]],
#
#          [[ 0.0133]],
#
#          ...,
#
#          [[ 0.0042]],
#
#          [[-0.0017]],
#
#          [[ 0.0047]]],
#
#
#         [[[ 0.0220]],
#
#          [[-0.0033]],
#
#          [[-0.0143]],
#
#          ...,
#
#          [[-0.0486]],
#
#          [[-0.0007]],
#
#          [[ 0.0819]]]], device='cuda:0'), 'block1.1.batchnorm3.weight': tensor([ 0.1833,  0.1897,  0.2106,  0.2341,  0.1985,  0.1921,  0.1989,  0.2085,
#          0.2080,  0.2184,  0.1823,  0.2283,  0.2077,  0.1829,  0.2010,  0.1927,
#          0.2324,  0.2084,  0.2041,  0.1704,  0.2132,  0.2261,  0.2052,  0.2178,
#          0.1384,  0.1510,  0.2428,  0.2232,  0.1950,  0.1715,  0.1959,  0.2609,
#          0.1871,  0.2115,  0.2173,  0.2019,  0.2011,  0.2183,  0.1645,  0.1319,
#          0.1908,  0.2305,  0.1954,  0.2463,  0.2485,  0.1659,  0.2402,  0.1912,
#          0.2166,  0.2307,  0.1939,  0.1800,  0.2254,  0.2280,  0.2147,  0.2591,
#          0.1928,  0.1663,  0.2088,  0.1883,  0.2107,  0.2105,  0.2275,  0.1585,
#         -1.4006e-02, -1.2066e-04,  2.4039e-02, -8.9892e-03, -2.0061e-02,
#          3.0549e-02, -4.1449e-03, -8.2515e-03, -3.0405e-02, -7.1919e-03,
#          9.0101e-03, -1.7555e-02,  2.6187e-03,  2.0267e-02, -4.8479e-03,
#          1.1256e-02, -3.0105e-03,  2.1053e-04,  1.0886e-02,  9.9974e-05,
#         -1.1556e-03,  2.5192e-02,  2.6972e-02,  1.4007e-03,  3.8591e-03,
#         -1.0834e-03,  6.7860e-03,  3.5505e-03,  1.3524e-02, -2.5940e-02,
#          7.5824e-03,  3.2925e-02,  1.5965e-02,  6.2100e-03, -1.5035e-02,
#          3.0990e-02,  2.4713e-02, -2.8050e-02,  1.6754e-02,  3.0870e-03,
#          8.5674e-03,  2.7021e-03,  2.9932e-03,  7.0720e-03, -1.6118e-02,
#          9.5989e-03,  1.9727e-02,  2.0672e-02, -8.8695e-03, -1.7845e-03,
#         -1.2900e-02,  2.0192e-02,  1.7540e-02, -7.2492e-03,  1.8278e-02,
#          4.2251e-02, -5.5056e-03,  2.0814e-02,  1.8590e-02,  2.6151e-03,
#         -2.0877e-02, -7.2842e-03,  2.2486e-02,  1.8298e-03,  2.0648e-02,
#          1.8071e-02], device='cuda:0'), 'block1.2.conv1_1x1.weight': tensor([[[[-0.0084]],
#
#          [[-0.0502]],
#
#          [[-0.0057]],
#
#          ...,
#
#          [[ 0.0081]],
#
#          [[ 0.0230]],
#
#          [[-0.0195]]],
#
#
#         [[[ 0.0339]],
#
#          [[ 0.0081]],
#
#          [[-0.0272]],
#
#          ...,
#
#          [[-0.0859]],
#
#          [[-0.0206]],
#
#          [[ 0.0114]]],
#
#
#         [[[-0.0060]],
#
#          [[-0.0089]],
#
#          [[ 0.0431]],
#
#          ...,
#
#          [[-0.0542]],
#
#          [[ 0.0710]],
#
#          [[ 0.0635]]],
#
#
#         ...,
#
#
#         [[[-0.0133]],
#
#          [[ 0.0269]],
#
#          [[-0.0287]],
#
#          ...,
#
#          [[ 0.0043]],
#
#          [[-0.0534]],
#
#          [[-0.0196]]],
#
#
#         [[[ 0.0164]],
#
#          [[ 0.0052]],
#
#          [[ 0.0545]],
#
#          ...,
#
#          [[-0.0304]],
#
#          [[ 0.0951]],
#
#          [[ 0.0527]]],
#
#
#         [[[-0.0093]],
#
#          [[ 0.0568]],
#
#          [[ 0.0120]],
#
#          ...,
#
#          [[-0.0474]],
#
#          [[-0.0067]],
#
#          [[-0.1107]]]], device='cuda:0'), 'block1.2.batchnorm1.weight': tensor([0.3057, 0.2586, 0.3404, 0.1982, 0.2042, 0.2095, 0.2834, 0.0569, 0.2589,
#         0.1932, 0.3499, 0.3452, 0.2048, 0.2469, 0.1187, 0.1929, 0.2317, 0.2350,
#         0.2541, 0.2148, 0.1683, 0.3889, 0.1737, 0.2388, 0.1944, 0.2394, 0.1825,
#         0.1617, 0.1988, 0.1716, 0.1618, 0.2325, 0.2137, 0.0997, 0.2636, 0.1752,
#         0.1422, 0.1806, 0.2144, 0.2446, 0.2195, 0.1936, 0.2436, 0.2625, 0.1805,
#         0.1747, 0.1900, 0.3980, 0.2724, 0.2519, 0.2223, 0.1729, 0.2868, 0.2736,
#         0.2042, 0.1294, 0.2240, 0.2506, 0.3632, 0.1659, 0.0966, 0.2349, 0.1436,
#         0.2080], device='cuda:0'), 'block1.2.batchnorm1.bias': tensor([ 0.0447, -0.0155,  0.0939, -0.0528, -0.0184,  0.1172,  0.0567, -0.0562,
#          0.0063,  0.0163,  0.1086, -0.0467,  0.0129,  0.1234, -0.0526, -0.0495,
#          0.0029,  0.0007, -0.0712, -0.0098,  0.0265,  0.1216, -0.0687, -0.0008,
#         -0.0701, -0.0499,  0.0673,  0.0165, -0.0213, -0.0510, -0.0623,  0.0603,
#          0.0065,  0.0136, -0.0372, -0.0704, -0.0366, -0.0347, -0.0148, -0.0218,
#         -0.0364, -0.0561,  0.0055,  0.0412, -0.0222,  0.0115,  0.0099,  0.0544,
#          0.0596,  0.0590,  0.0308, -0.0325, -0.1161,  0.0807,  0.0080, -0.1036,
#          0.0181, -0.0183,  0.0851,  0.0031, -0.0137, -0.0265,  0.0134, -0.0425],
#        device='cuda:0'), 'block1.2.conv2_3x3.weight': tensor([[[[ 9.5833e-04, -9.4855e-03,  1.7562e-02],
#           [ 3.3077e-02,  6.6495e-03,  2.7858e-02],
#           [-1.9354e-02, -5.2091e-02,  1.7556e-02]],
#
#          [[ 3.7374e-03,  1.4945e-02,  5.0304e-02],
#           [ 1.5528e-02,  3.8570e-02,  1.9673e-02],
#           [ 6.6394e-03,  2.4451e-02,  1.9520e-03]],
#
#          [[-5.6255e-03,  1.7056e-02, -8.9353e-03],
#           [ 2.7155e-02, -8.5988e-03, -1.6503e-02],
#           [-1.1212e-02, -1.0789e-02, -2.2834e-02]],
#
#          ...,
#
#          [[-3.6085e-02,  7.7678e-02,  4.1196e-02],
#           [ 3.6451e-02, -1.7215e-02, -1.6592e-02],
# ...
#           [-3.2735e-03, -1.7425e-03, -2.2161e-04],
#           [ 1.6163e-03, -1.6727e-03, -6.7404e-04]],
#
#          [[-1.2277e-03,  2.2508e-04,  3.0790e-03],
#           [ 1.4301e-03,  2.0978e-03, -2.7805e-03],
#           [ 1.4361e-03,  1.5349e-04, -4.7893e-04]],
#
#          [[-3.0180e-03, -2.7352e-03, -2.4675e-03],
#           [-1.4210e-03,  1.1523e-03,  3.2348e-03],
#           [-6.7168e-04, -2.3907e-03, -2.9854e-03]],
#
#          ...,
#
#          [[-1.7868e-03, -7.7553e-04,  2.4212e-03],
#           [-2.3808e-03,  4.3757e-03,  2.6900e-03],
#           [-3.5825e-04,  3.0868e-03,  1.3934e-05]],
#
#          [[-1.3616e-03, -2.5538e-03, -3.1887e-03],
#           [ 2.9847e-03, -7.2724e-04, -1.7770e-03],
#           [-2.1467e-03,  1.1950e-03,  2.6605e-03]],
#
#          [[-1.1127e-03, -1.4491e-03, -2.9078e-03],
#           [-3.3626e-04, -8.4600e-04,  1.8057e-03],
#           [-1.2432e-03, -2.8004e-03,  3.0382e-03]]],
#         -1.5305e-04,  1.0595e-03, -1.7094e-03,  1.5747e-03,  1.3214e-03,
#          4.9332e-04, -1.2103e-06, -1.2406e-03, -2.9518e-03,  1.1458e-03,
#         -2.3279e-03, -3.8274e-04,  8.3671e-04,  3.3467e-04, -1.3393e-03,
#         -8.4417e-04, -2.1481e-03, -3.0571e-03,  1.4259e-03,  2.1228e-04,
#         -7.3809e-04, -3.4064e-03,  2.1448e-03, -3.2438e-03,  3.1628e-04,
#          2.0322e-03, -7.7233e-04, -3.2220e-04, -3.0323e-03,  1.1225e-03,
#          2.3113e-03, -8.3489e-04, -1.2241e-03, -1.5472e-03,  1.5115e-03,
#          2.1960e-03, -2.7762e-03,  2.1829e-03, -3.2017e-03,  6.0446e-04,
#          3.2556e-03, -2.3898e-03,  1.4061e-03,  2.5740e-04,  4.1026e-04,
#          1.9824e-03, -2.0729e-03,  1.3883e-03, -1.5535e-03,  2.6954e-03,
#         -2.5726e-03, -8.9434e-04,  3.4878e-04,  2.5570e-03, -2.8888e-04,
#          2.7237e-03, -2.5893e-03, -1.5881e-03,  3.7131e-04, -2.0465e-04,
#         -1.2887e-03, -8.7596e-04, -2.1008e-04,  1.4793e-03,  2.5702e-03,
#         -8.8426e-04,  4.6676e-04,  2.6314e-03, -1.6791e-03, -3.0358e-05,
#          1.9096e-03,  5.0907e-05, -2.1893e-03, -1.1137e-03, -9.9173e-04,
#         -3.2503e-03,  1.6080e-03, -5.1408e-05,  2.9322e-03, -3.2482e-04,
#          1.6892e-03, -1.2029e-03, -2.9490e-04,  2.0615e-03, -1.7267e-03,
#         -1.8473e-03, -2.6075e-04, -1.2076e-03,  3.1538e-05, -1.8969e-03,
#          1.3948e-03, -1.0561e-04, -1.5269e-03, -4.8172e-04,  3.2629e-03,
#          3.7743e-03, -4.9604e-04, -9.0305e-04, -4.6796e-04,  4.0414e-04,
#          7.5316e-05,  1.2811e-03, -6.6782e-04,  4.6516e-04,  3.2475e-03,
#          8.8091e-04,  6.1172e-04], device='cuda:0'), 'block4.2.conv3_1x1.weight': tensor([[[[-7.6843e-03]],
#
#          [[-9.2876e-03]],
#
#          [[-1.0295e-02]],
#
#          ...,
#
#          [[-7.6310e-03]],
#
#          [[-6.4414e-03]],
#
#          [[-2.3662e-03]]],
#
#
#         [[[-4.8364e-03]],
#
#          [[-4.6430e-03]],
#
#          [[-7.9355e-03]],
#
#          ...,
#
#          [[-8.2080e-03]],
#
#          [[-1.0452e-02]],
#
#          [[ 8.4229e-03]]],
#
#
#         [[[-2.0239e-03]],
#
#          [[ 8.6933e-03]],
#
#          [[-4.0521e-03]],
#
#          ...,
#
#          [[ 7.9588e-03]],
#
#          [[-9.3158e-04]],
#
#          [[-7.2630e-03]]],
#
#
#         ...,
#
#
#         [[[ 9.4886e-03]],
#
#          [[-7.8537e-03]],
#
#          [[-3.7815e-03]],
#
#          ...,
#
#          [[ 4.2317e-03]],
#
#          [[-5.8908e-03]],
#
#          [[ 5.5214e-03]]],
#
#
#         [[[ 2.9846e-03]],
#
#          [[-8.1395e-03]],
#
#          [[ 7.4315e-03]],
#
#          ...,
#
#          [[-4.7248e-03]],
#
#          [[ 4.0992e-03]],
#
#          [[-9.8920e-03]]],
#
#
#         [[[-9.3315e-03]],
#
#          [[-5.3685e-03]],
#
#          [[ 2.8930e-03]],
#
#          ...,
#
#          [[ 8.7559e-06]],
#
#          [[-2.9364e-03]],
#
#          [[-7.5240e-03]]]], device='cuda:0'), 'block4.2.batchnorm3.weight': tensor([0.2171, 0.1663, 0.1492,  ..., 0.1942, 0.2046, 0.2060], device='cuda:0'), 'block4.2.batchnorm3.bias': tensor([-0.0331, -0.0346, -0.0389,  ..., -0.0423, -0.0452, -0.0454],
#        device='cuda:0'), 'fc1.weight': tensor([[-0.0100,  0.0548, -0.0040,  ..., -0.0363, -0.0040,  0.0012],
#         [ 0.0006, -0.0027, -0.0195,  ..., -0.0870,  0.0194,  0.0068],
#         [ 0.0063, -0.0254,  0.0050,  ..., -0.0133,  0.0008,  0.0029],
#         ...,
#         [ 0.0058, -0.0068,  0.0336,  ...,  0.0552, -0.0125,  0.0047],
#         [-0.0143, -0.0202,  0.0134,  ..., -0.0175,  0.0123,  0.0061],
#         [ 0.0047, -0.0009,  0.0606,  ...,  0.1423, -0.0039, -0.0097]],
#        device='cuda:0'), 'fc1.bias': tensor([-0.0130, -0.0187,  0.0319, -0.0439,  0.0255, -0.0045, -0.0200, -0.0414,
#          0.0683,  0.0033], device='cuda:0')}

# %% [markdown]
# # checking its performance on each number in MNIST

# %%
def test():

    correct = 0
    total = 0

    wrong_counts = [0 for i in range(10)]

    with torch.no_grad():

        for data in tqdm(test_loader , desc = 'Testing'):

            x,y = data

            x = x.to(device)
            y = y.to(device)

            output = model(x)

            for idx , i in enumerate(output):

                if torch.argmax(i) == y[idx]:
                    
                    correct += 1
                else:
                    wrong_counts[y[idx]] +=1

                total+=1
        
        print(f'Accuracy : {round(correct/total , 3)}')

        for i in range(len(wrong_counts)):

            print(f'wrong counts for the digit {i} : {wrong_counts[i]}')


test()
# Out:
# Testing: 100%|██████████| 1000/1000 [00:06<00:00, 163.37it/s]
# Accuracy : 0.943
# wrong counts for the digit 0 : 21
# wrong counts for the digit 1 : 10
# wrong counts for the digit 2 : 73
# wrong counts for the digit 3 : 143
# wrong counts for the digit 4 : 34
# wrong counts for the digit 5 : 25
# wrong counts for the digit 6 : 36
# wrong counts for the digit 7 : 69
# wrong counts for the digit 8 : 70
# wrong counts for the digit 9 : 93

# %%
total_params = 0
for name, module in model.named_modules():
    if isinstance(module, (nn.Conv2d, nn.Linear)):
        weights_params = module.weight.nelement()
        bias_params = module.bias.nelement() if module.bias is not None else 0
        total_params += weights_params + bias_params
        print(f'Layer {name}: W: {module.weight.shape} + B: {module.bias.shape if module.bias is not None else "No bias"}')
        print(f'Parameters: {weights_params + bias_params}')

print(f'Total number of parameters: {total_params:,}')
# Out:
# Layer conv1: W: torch.Size([64, 1, 7, 7]) + B: No bias
# Parameters: 3136
# Layer block1.0.projection.0: W: torch.Size([256, 64, 1, 1]) + B: No bias
# Parameters: 16384
# Layer block1.0.conv1_1x1: W: torch.Size([64, 64, 1, 1]) + B: No bias
# Parameters: 4096
# Layer block1.0.conv2_3x3: W: torch.Size([64, 64, 3, 3]) + B: No bias
# Parameters: 36864
# Layer block1.0.conv3_1x1: W: torch.Size([256, 64, 1, 1]) + B: No bias
# Parameters: 16384
# Layer block1.1.conv1_1x1: W: torch.Size([64, 256, 1, 1]) + B: No bias
# Parameters: 16384
# Layer block1.1.conv2_3x3: W: torch.Size([64, 64, 3, 3]) + B: No bias
# Parameters: 36864
# Layer block1.1.conv3_1x1: W: torch.Size([256, 64, 1, 1]) + B: No bias
# Parameters: 16384
# Layer block1.2.conv1_1x1: W: torch.Size([64, 256, 1, 1]) + B: No bias
# Parameters: 16384
# Layer block1.2.conv2_3x3: W: torch.Size([64, 64, 3, 3]) + B: No bias
# Parameters: 36864
# Layer block1.2.conv3_1x1: W: torch.Size([256, 64, 1, 1]) + B: No bias
# Parameters: 16384
# Layer block2.0.projection.0: W: torch.Size([512, 256, 1, 1]) + B: No bias
# Parameters: 131072
# Layer block2.0.conv1_1x1: W: torch.Size([128, 256, 1, 1]) + B: No bias
# Parameters: 32768
# Layer block2.0.conv2_3x3: W: torch.Size([128, 128, 3, 3]) + B: No bias
# Parameters: 147456
# Layer block2.0.conv3_1x1: W: torch.Size([512, 128, 1, 1]) + B: No bias
# Parameters: 65536
# Layer block2.1.conv1_1x1: W: torch.Size([128, 512, 1, 1]) + B: No bias
# Parameters: 65536
# Layer block2.1.conv2_3x3: W: torch.Size([128, 128, 3, 3]) + B: No bias
# Parameters: 147456
# Layer block2.1.conv3_1x1: W: torch.Size([512, 128, 1, 1]) + B: No bias
# Parameters: 65536
# Layer block2.2.conv1_1x1: W: torch.Size([128, 512, 1, 1]) + B: No bias
# Parameters: 65536
# Layer block2.2.conv2_3x3: W: torch.Size([128, 128, 3, 3]) + B: No bias
# Parameters: 147456
# Layer block2.2.conv3_1x1: W: torch.Size([512, 128, 1, 1]) + B: No bias
# Parameters: 65536
# Layer block2.3.conv1_1x1: W: torch.Size([128, 512, 1, 1]) + B: No bias
# Parameters: 65536
# Layer block2.3.conv2_3x3: W: torch.Size([128, 128, 3, 3]) + B: No bias
# Parameters: 147456
# Layer block2.3.conv3_1x1: W: torch.Size([512, 128, 1, 1]) + B: No bias
# Parameters: 65536
# Layer block3.0.projection.0: W: torch.Size([1024, 512, 1, 1]) + B: No bias
# Parameters: 524288
# Layer block3.0.conv1_1x1: W: torch.Size([256, 512, 1, 1]) + B: No bias
# Parameters: 131072
# Layer block3.0.conv2_3x3: W: torch.Size([256, 256, 3, 3]) + B: No bias
# Parameters: 589824
# Layer block3.0.conv3_1x1: W: torch.Size([1024, 256, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.1.conv1_1x1: W: torch.Size([256, 1024, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.1.conv2_3x3: W: torch.Size([256, 256, 3, 3]) + B: No bias
# Parameters: 589824
# Layer block3.1.conv3_1x1: W: torch.Size([1024, 256, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.2.conv1_1x1: W: torch.Size([256, 1024, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.2.conv2_3x3: W: torch.Size([256, 256, 3, 3]) + B: No bias
# Parameters: 589824
# Layer block3.2.conv3_1x1: W: torch.Size([1024, 256, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.3.conv1_1x1: W: torch.Size([256, 1024, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.3.conv2_3x3: W: torch.Size([256, 256, 3, 3]) + B: No bias
# Parameters: 589824
# Layer block3.3.conv3_1x1: W: torch.Size([1024, 256, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.4.conv1_1x1: W: torch.Size([256, 1024, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.4.conv2_3x3: W: torch.Size([256, 256, 3, 3]) + B: No bias
# Parameters: 589824
# Layer block3.4.conv3_1x1: W: torch.Size([1024, 256, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.5.conv1_1x1: W: torch.Size([256, 1024, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block3.5.conv2_3x3: W: torch.Size([256, 256, 3, 3]) + B: No bias
# Parameters: 589824
# Layer block3.5.conv3_1x1: W: torch.Size([1024, 256, 1, 1]) + B: No bias
# Parameters: 262144
# Layer block4.0.projection.0: W: torch.Size([2048, 1024, 1, 1]) + B: No bias
# Parameters: 2097152
# Layer block4.0.conv1_1x1: W: torch.Size([512, 1024, 1, 1]) + B: No bias
# Parameters: 524288
# Layer block4.0.conv2_3x3: W: torch.Size([512, 512, 3, 3]) + B: No bias
# Parameters: 2359296
# Layer block4.0.conv3_1x1: W: torch.Size([2048, 512, 1, 1]) + B: No bias
# Parameters: 1048576
# Layer block4.1.conv1_1x1: W: torch.Size([512, 2048, 1, 1]) + B: No bias
# Parameters: 1048576
# Layer block4.1.conv2_3x3: W: torch.Size([512, 512, 3, 3]) + B: No bias
# Parameters: 2359296
# Layer block4.1.conv3_1x1: W: torch.Size([2048, 512, 1, 1]) + B: No bias
# Parameters: 1048576
# Layer block4.2.conv1_1x1: W: torch.Size([512, 2048, 1, 1]) + B: No bias
# Parameters: 1048576
# Layer block4.2.conv2_3x3: W: torch.Size([512, 512, 3, 3]) + B: No bias
# Parameters: 2359296
# Layer block4.2.conv3_1x1: W: torch.Size([2048, 512, 1, 1]) + B: No bias
# Parameters: 1048576
# Layer fc1: W: torch.Size([10, 2048]) + B: torch.Size([10])
# Parameters: 20490
# Total number of parameters: 23,469,130

# %%
from torchsummary import summary

summary(model, (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 14, 14]           3,136
#        BatchNorm2d-2           [-1, 64, 14, 14]             128
#               ReLU-3           [-1, 64, 14, 14]               0
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#             Conv2d-5             [-1, 64, 7, 7]           4,096
#        BatchNorm2d-6             [-1, 64, 7, 7]             128
#               ReLU-7             [-1, 64, 7, 7]               0
#             Conv2d-8             [-1, 64, 7, 7]          36,864
#        BatchNorm2d-9             [-1, 64, 7, 7]             128
#              ReLU-10             [-1, 64, 7, 7]               0
#            Conv2d-11            [-1, 256, 7, 7]          16,384
#       BatchNorm2d-12            [-1, 256, 7, 7]             512
#            Conv2d-13            [-1, 256, 7, 7]          16,384
#       BatchNorm2d-14            [-1, 256, 7, 7]             512
#              ReLU-15            [-1, 256, 7, 7]               0
#        Bottleneck-16            [-1, 256, 7, 7]               0
#            Conv2d-17             [-1, 64, 7, 7]          16,384
#       BatchNorm2d-18             [-1, 64, 7, 7]             128
#              ReLU-19             [-1, 64, 7, 7]               0
#            Conv2d-20             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-21             [-1, 64, 7, 7]             128
#              ReLU-22             [-1, 64, 7, 7]               0
#            Conv2d-23            [-1, 256, 7, 7]          16,384
#       BatchNorm2d-24            [-1, 256, 7, 7]             512
#              ReLU-25            [-1, 256, 7, 7]               0
#        Bottleneck-26            [-1, 256, 7, 7]               0
#            Conv2d-27             [-1, 64, 7, 7]          16,384
#       BatchNorm2d-28             [-1, 64, 7, 7]             128
#              ReLU-29             [-1, 64, 7, 7]               0
#            Conv2d-30             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-31             [-1, 64, 7, 7]             128
#              ReLU-32             [-1, 64, 7, 7]               0
#            Conv2d-33            [-1, 256, 7, 7]          16,384
#       BatchNorm2d-34            [-1, 256, 7, 7]             512
#              ReLU-35            [-1, 256, 7, 7]               0
#        Bottleneck-36            [-1, 256, 7, 7]               0
#            Conv2d-37            [-1, 128, 7, 7]          32,768
#       BatchNorm2d-38            [-1, 128, 7, 7]             256
#              ReLU-39            [-1, 128, 7, 7]               0
#            Conv2d-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#            Conv2d-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#            Conv2d-45            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-46            [-1, 512, 4, 4]           1,024
#              ReLU-47            [-1, 512, 4, 4]               0
#        Bottleneck-48            [-1, 512, 4, 4]               0
#            Conv2d-49            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#            Conv2d-52            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-53            [-1, 128, 4, 4]             256
#              ReLU-54            [-1, 128, 4, 4]               0
#            Conv2d-55            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 512, 4, 4]           1,024
#              ReLU-57            [-1, 512, 4, 4]               0
#        Bottleneck-58            [-1, 512, 4, 4]               0
#            Conv2d-59            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-60            [-1, 128, 4, 4]             256
#              ReLU-61            [-1, 128, 4, 4]               0
#            Conv2d-62            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-63            [-1, 128, 4, 4]             256
#              ReLU-64            [-1, 128, 4, 4]               0
#            Conv2d-65            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-66            [-1, 512, 4, 4]           1,024
#              ReLU-67            [-1, 512, 4, 4]               0
#        Bottleneck-68            [-1, 512, 4, 4]               0
#            Conv2d-69            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-70            [-1, 128, 4, 4]             256
#              ReLU-71            [-1, 128, 4, 4]               0
#            Conv2d-72            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-73            [-1, 128, 4, 4]             256
#              ReLU-74            [-1, 128, 4, 4]               0
#            Conv2d-75            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-76            [-1, 512, 4, 4]           1,024
#              ReLU-77            [-1, 512, 4, 4]               0
#        Bottleneck-78            [-1, 512, 4, 4]               0
#            Conv2d-79            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-80            [-1, 256, 4, 4]             512
#              ReLU-81            [-1, 256, 4, 4]               0
#            Conv2d-82            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-83            [-1, 256, 2, 2]             512
#              ReLU-84            [-1, 256, 2, 2]               0
#            Conv2d-85           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-86           [-1, 1024, 2, 2]           2,048
#            Conv2d-87           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-88           [-1, 1024, 2, 2]           2,048
#              ReLU-89           [-1, 1024, 2, 2]               0
#        Bottleneck-90           [-1, 1024, 2, 2]               0
#            Conv2d-91            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-92            [-1, 256, 2, 2]             512
#              ReLU-93            [-1, 256, 2, 2]               0
#            Conv2d-94            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#            Conv2d-97           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-98           [-1, 1024, 2, 2]           2,048
#              ReLU-99           [-1, 1024, 2, 2]               0
#       Bottleneck-100           [-1, 1024, 2, 2]               0
#           Conv2d-101            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-102            [-1, 256, 2, 2]             512
#             ReLU-103            [-1, 256, 2, 2]               0
#           Conv2d-104            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-105            [-1, 256, 2, 2]             512
#             ReLU-106            [-1, 256, 2, 2]               0
#           Conv2d-107           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-108           [-1, 1024, 2, 2]           2,048
#             ReLU-109           [-1, 1024, 2, 2]               0
#       Bottleneck-110           [-1, 1024, 2, 2]               0
#           Conv2d-111            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-112            [-1, 256, 2, 2]             512
#             ReLU-113            [-1, 256, 2, 2]               0
#           Conv2d-114            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-115            [-1, 256, 2, 2]             512
#             ReLU-116            [-1, 256, 2, 2]               0
#           Conv2d-117           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-118           [-1, 1024, 2, 2]           2,048
#             ReLU-119           [-1, 1024, 2, 2]               0
#       Bottleneck-120           [-1, 1024, 2, 2]               0
#           Conv2d-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#           Conv2d-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#           Conv2d-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
#             ReLU-129           [-1, 1024, 2, 2]               0
#       Bottleneck-130           [-1, 1024, 2, 2]               0
#           Conv2d-131            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-132            [-1, 256, 2, 2]             512
#             ReLU-133            [-1, 256, 2, 2]               0
#           Conv2d-134            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-135            [-1, 256, 2, 2]             512
#             ReLU-136            [-1, 256, 2, 2]               0
#           Conv2d-137           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-138           [-1, 1024, 2, 2]           2,048
#             ReLU-139           [-1, 1024, 2, 2]               0
#       Bottleneck-140           [-1, 1024, 2, 2]               0
#           Conv2d-141            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-142            [-1, 512, 2, 2]           1,024
#             ReLU-143            [-1, 512, 2, 2]               0
#           Conv2d-144            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-145            [-1, 512, 1, 1]           1,024
#             ReLU-146            [-1, 512, 1, 1]               0
#           Conv2d-147           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 1, 1]           4,096
#           Conv2d-149           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 1, 1]           4,096
#             ReLU-151           [-1, 2048, 1, 1]               0
#       Bottleneck-152           [-1, 2048, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-154            [-1, 512, 1, 1]           1,024
#             ReLU-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-157            [-1, 512, 1, 1]           1,024
#             ReLU-158            [-1, 512, 1, 1]               0
#           Conv2d-159           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 1, 1]           4,096
#             ReLU-161           [-1, 2048, 1, 1]               0
#       Bottleneck-162           [-1, 2048, 1, 1]               0
#           Conv2d-163            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-164            [-1, 512, 1, 1]           1,024
#             ReLU-165            [-1, 512, 1, 1]               0
#           Conv2d-166            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-167            [-1, 512, 1, 1]           1,024
#             ReLU-168            [-1, 512, 1, 1]               0
#           Conv2d-169           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 1, 1]           4,096
#             ReLU-171           [-1, 2048, 1, 1]               0
#       Bottleneck-172           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                   [-1, 10]          20,490
# ================================================================
# Total params: 23,522,250
# Trainable params: 23,522,250
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 5.18
# Params size (MB): 89.73
# Estimated Total Size (MB): 94.92
# ----------------------------------------------------------------

# %% [markdown]
# # Now lets define a LORA class

# %%
class LoRAParametrization(nn.Module):
    def __init__(self, features_in, features_out, rank=1, alpha=1, device='cpu'):
        super().__init__()
        # Section 4.1 of the paper: 
        #   We use a random Gaussian initialization for A and zero for B, so ∆W = BA is zero at the beginning of training
        self.lora_A = nn.Parameter(torch.zeros((rank,features_out)).to(device))
        self.lora_B = nn.Parameter(torch.zeros((features_in, rank)).to(device))
        nn.init.normal_(self.lora_A, mean=0, std=1)
        
        # Section 4.1 of the paper: 
        #   We then scale ∆Wx by α/r , where α is a constant in r. 
        #   When optimizing with Adam, tuning α is roughly the same as tuning the learning rate if we scale the initialization appropriately. 
        #   As a result, we simply set α to the first r we try and do not tune it. 
        #   This scaling helps to reduce the need to retune hyperparameters when we vary r.
        self.scale = alpha / rank
        self.enabled = True

    def forward(self, original_weights):
        if self.enabled:
            # Return W + (B*A)*scale
            return original_weights + torch.matmul(self.lora_B, self.lora_A).view(original_weights.shape) * self.scale
        else:
            return original_weights

# %% [markdown]
# # Now lets define function for conv layer parameterization and linear layer parametrization

# %%
import torch.nn.utils.parametrize as parametrize

def conv_layer_parameterization(layer , device , rank =1 , lora_alpha = 1):

    features_in = layer.weight.shape[1] * layer.weight.shape[2] * layer.weight.shape[3]

    features_out = layer.weight.shape[0]

    return LoRAParametrization(features_in , features_out , rank = rank , alpha=lora_alpha , device = device)

def linear_layer_parameterization(layer , device , rank = 1, lora_alpha=1):

    features_in , features_out = layer.weight.shape

    return LoRAParametrization(

        features_in,features_out,rank=rank,alpha=lora_alpha,device=device
    )



def add_lora_to_model(model, device, rank=1, lora_alpha=1):
    # Add LoRA to conv1
    if isinstance(model.conv1, nn.Conv2d):
        parametrize.register_parametrization(
            model.conv1, "weight", conv_layer_parameterization(model.conv1, device, rank, lora_alpha)
        )

    # Add LoRA to blocks
    for block_name in ['block1', 'block2', 'block3', 'block4']:
        block = getattr(model, block_name)
        for sub_block in block:
            for layer_name in ['conv1_1x1', 'conv2_3x3', 'conv3_1x1']:
                layer = getattr(sub_block, layer_name)
                if isinstance(layer, nn.Conv2d):
                    parametrize.register_parametrization(
                        layer, "weight", conv_layer_parameterization(layer, device, rank, lora_alpha)
                    )
            
            # Add LoRA to projection layer if it exists
            if hasattr(sub_block, 'projection') and isinstance(sub_block.projection[0], nn.Conv2d):
                parametrize.register_parametrization(
                    sub_block.projection[0], "weight", conv_layer_parameterization(sub_block.projection[0], device, rank, lora_alpha)
                )

    # Add LoRA to fc1
    if isinstance(model.fc1, nn.Linear):
        parametrize.register_parametrization(
            model.fc1, "weight", linear_layer_parameterization(model.fc1, device, rank, lora_alpha)
        )

def enable_disable_lora(model, enabled=True):
    for module in model.modules():
        if isinstance(module, (nn.Conv2d, nn.Linear)) and hasattr(module, 'parametrizations'):
            module.parametrizations["weight"][0].enabled = enabled

# %%
def count_parameters(model):
    total_params_original = 0
    total_params_lora = 0
    
    for name, module in model.named_modules():
        if isinstance(module, (nn.Conv2d, nn.Linear)):
            weights_params = module.weight.nelement()
            bias_params = module.bias.nelement() if module.bias is not None else 0
            total_params_original += weights_params + bias_params
            
            if hasattr(module, 'parametrizations'):
                lora_params = module.parametrizations["weight"][0].lora_A.nelement() + \
                              module.parametrizations["weight"][0].lora_B.nelement()
                total_params_lora += lora_params
                
                print(f'Layer {name}:')
                print(f'  W: {module.weight.shape}')
                print(f'  B: {module.bias.shape if module.bias is not None else "No bias"}')
                print(f'  Lora_A: {module.parametrizations["weight"][0].lora_A.shape}')
                print(f'  Lora_B: {module.parametrizations["weight"][0].lora_B.shape}')
                print(f'  Parameters: {weights_params + bias_params + lora_params}')
            else:
                print(f'Layer {name}:')
                print(f'  W: {module.weight.shape}')
                print(f'  B: {module.bias.shape if module.bias is not None else "No bias"}')
                print(f'  Parameters: {weights_params + bias_params}')
    
    print(f'\nTotal number of parameters (original): {total_params_original:,}')
    print(f'Total number of parameters (original + LoRA): {total_params_original + total_params_lora:,}')
    print(f'Parameters introduced by LoRA: {total_params_lora:,}')
    parameters_increment = (total_params_lora / total_params_original) * 100
    print(f'Parameters increment: {parameters_increment:.3f}%')

# %%
print("Parameters before adding LoRA:")
count_parameters(model)

# Add LoRA to the model
add_lora_to_model(model, device, rank=4, lora_alpha=1)

# Count parameters after adding LoRA
print("\nParameters after adding LoRA:")
count_parameters(model)

# Example of enabling/disabling LoRA
enable_disable_lora(model, enabled=True)
# Out:
# Parameters before adding LoRA:
# Layer conv1:
#   W: torch.Size([64, 1, 7, 7])
#   B: No bias
#   Parameters: 3136
# Layer block1.0.projection.0:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Parameters: 16384
# Layer block1.0.conv1_1x1:
#   W: torch.Size([64, 64, 1, 1])
#   B: No bias
#   Parameters: 4096
# Layer block1.0.conv2_3x3:
#   W: torch.Size([64, 64, 3, 3])
#   B: No bias
#   Parameters: 36864
# Layer block1.0.conv3_1x1:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Parameters: 16384
# Layer block1.1.conv1_1x1:
#   W: torch.Size([64, 256, 1, 1])
#   B: No bias
#   Parameters: 16384
# Layer block1.1.conv2_3x3:
#   W: torch.Size([64, 64, 3, 3])
#   B: No bias
#   Parameters: 36864
# Layer block1.1.conv3_1x1:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Parameters: 16384
# Layer block1.2.conv1_1x1:
#   W: torch.Size([64, 256, 1, 1])
#   B: No bias
#   Parameters: 16384
# Layer block1.2.conv2_3x3:
#   W: torch.Size([64, 64, 3, 3])
#   B: No bias
#   Parameters: 36864
# Layer block1.2.conv3_1x1:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Parameters: 16384
# Layer block2.0.projection.0:
#   W: torch.Size([512, 256, 1, 1])
#   B: No bias
#   Parameters: 131072
# Layer block2.0.conv1_1x1:
#   W: torch.Size([128, 256, 1, 1])
#   B: No bias
#   Parameters: 32768
# Layer block2.0.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Parameters: 147456
# Layer block2.0.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Parameters: 65536
# Layer block2.1.conv1_1x1:
#   W: torch.Size([128, 512, 1, 1])
#   B: No bias
#   Parameters: 65536
# Layer block2.1.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Parameters: 147456
# Layer block2.1.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Parameters: 65536
# Layer block2.2.conv1_1x1:
#   W: torch.Size([128, 512, 1, 1])
#   B: No bias
#   Parameters: 65536
# Layer block2.2.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Parameters: 147456
# Layer block2.2.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Parameters: 65536
# Layer block2.3.conv1_1x1:
#   W: torch.Size([128, 512, 1, 1])
#   B: No bias
#   Parameters: 65536
# Layer block2.3.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Parameters: 147456
# Layer block2.3.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Parameters: 65536
# Layer block3.0.projection.0:
#   W: torch.Size([1024, 512, 1, 1])
#   B: No bias
#   Parameters: 524288
# Layer block3.0.conv1_1x1:
#   W: torch.Size([256, 512, 1, 1])
#   B: No bias
#   Parameters: 131072
# Layer block3.0.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Parameters: 589824
# Layer block3.0.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.1.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.1.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Parameters: 589824
# Layer block3.1.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.2.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.2.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Parameters: 589824
# Layer block3.2.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.3.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.3.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Parameters: 589824
# Layer block3.3.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.4.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.4.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Parameters: 589824
# Layer block3.4.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.5.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block3.5.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Parameters: 589824
# Layer block3.5.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Parameters: 262144
# Layer block4.0.projection.0:
#   W: torch.Size([2048, 1024, 1, 1])
#   B: No bias
#   Parameters: 2097152
# Layer block4.0.conv1_1x1:
#   W: torch.Size([512, 1024, 1, 1])
#   B: No bias
#   Parameters: 524288
# Layer block4.0.conv2_3x3:
#   W: torch.Size([512, 512, 3, 3])
#   B: No bias
#   Parameters: 2359296
# Layer block4.0.conv3_1x1:
#   W: torch.Size([2048, 512, 1, 1])
#   B: No bias
#   Parameters: 1048576
# Layer block4.1.conv1_1x1:
#   W: torch.Size([512, 2048, 1, 1])
#   B: No bias
#   Parameters: 1048576
# Layer block4.1.conv2_3x3:
#   W: torch.Size([512, 512, 3, 3])
#   B: No bias
#   Parameters: 2359296
# Layer block4.1.conv3_1x1:
#   W: torch.Size([2048, 512, 1, 1])
#   B: No bias
#   Parameters: 1048576
# Layer block4.2.conv1_1x1:
#   W: torch.Size([512, 2048, 1, 1])
#   B: No bias
#   Parameters: 1048576
# Layer block4.2.conv2_3x3:
#   W: torch.Size([512, 512, 3, 3])
#   B: No bias
#   Parameters: 2359296
# Layer block4.2.conv3_1x1:
#   W: torch.Size([2048, 512, 1, 1])
#   B: No bias
#   Parameters: 1048576
# Layer fc1:
#   W: torch.Size([10, 2048])
#   B: torch.Size([10])
#   Parameters: 20490
#
# Total number of parameters (original): 23,469,130
# Total number of parameters (original + LoRA): 23,469,130
# Parameters introduced by LoRA: 0
# Parameters increment: 0.000%
#
# Parameters after adding LoRA:
# Layer conv1:
#   W: torch.Size([64, 1, 7, 7])
#   B: No bias
#   Lora_A: torch.Size([4, 64])
#   Lora_B: torch.Size([49, 4])
#   Parameters: 3588
# Layer block1.0.projection.0:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([64, 4])
#   Parameters: 17664
# Layer block1.0.conv1_1x1:
#   W: torch.Size([64, 64, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 64])
#   Lora_B: torch.Size([64, 4])
#   Parameters: 4608
# Layer block1.0.conv2_3x3:
#   W: torch.Size([64, 64, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 64])
#   Lora_B: torch.Size([576, 4])
#   Parameters: 39424
# Layer block1.0.conv3_1x1:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([64, 4])
#   Parameters: 17664
# Layer block1.1.conv1_1x1:
#   W: torch.Size([64, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 64])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 17664
# Layer block1.1.conv2_3x3:
#   W: torch.Size([64, 64, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 64])
#   Lora_B: torch.Size([576, 4])
#   Parameters: 39424
# Layer block1.1.conv3_1x1:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([64, 4])
#   Parameters: 17664
# Layer block1.2.conv1_1x1:
#   W: torch.Size([64, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 64])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 17664
# Layer block1.2.conv2_3x3:
#   W: torch.Size([64, 64, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 64])
#   Lora_B: torch.Size([576, 4])
#   Parameters: 39424
# Layer block1.2.conv3_1x1:
#   W: torch.Size([256, 64, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([64, 4])
#   Parameters: 17664
# Layer block2.0.projection.0:
#   W: torch.Size([512, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 134144
# Layer block2.0.conv1_1x1:
#   W: torch.Size([128, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 34304
# Layer block2.0.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([1152, 4])
#   Parameters: 152576
# Layer block2.0.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([128, 4])
#   Parameters: 68096
# Layer block2.1.conv1_1x1:
#   W: torch.Size([128, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 68096
# Layer block2.1.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([1152, 4])
#   Parameters: 152576
# Layer block2.1.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([128, 4])
#   Parameters: 68096
# Layer block2.2.conv1_1x1:
#   W: torch.Size([128, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 68096
# Layer block2.2.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([1152, 4])
#   Parameters: 152576
# Layer block2.2.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([128, 4])
#   Parameters: 68096
# Layer block2.3.conv1_1x1:
#   W: torch.Size([128, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 68096
# Layer block2.3.conv2_3x3:
#   W: torch.Size([128, 128, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 128])
#   Lora_B: torch.Size([1152, 4])
#   Parameters: 152576
# Layer block2.3.conv3_1x1:
#   W: torch.Size([512, 128, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([128, 4])
#   Parameters: 68096
# Layer block3.0.projection.0:
#   W: torch.Size([1024, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 1024])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 530432
# Layer block3.0.conv1_1x1:
#   W: torch.Size([256, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 134144
# Layer block3.0.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([2304, 4])
#   Parameters: 600064
# Layer block3.0.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 1024])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 267264
# Layer block3.1.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([1024, 4])
#   Parameters: 267264
# Layer block3.1.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([2304, 4])
#   Parameters: 600064
# Layer block3.1.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 1024])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 267264
# Layer block3.2.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([1024, 4])
#   Parameters: 267264
# Layer block3.2.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([2304, 4])
#   Parameters: 600064
# Layer block3.2.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 1024])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 267264
# Layer block3.3.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([1024, 4])
#   Parameters: 267264
# Layer block3.3.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([2304, 4])
#   Parameters: 600064
# Layer block3.3.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 1024])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 267264
# Layer block3.4.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([1024, 4])
#   Parameters: 267264
# Layer block3.4.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([2304, 4])
#   Parameters: 600064
# Layer block3.4.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 1024])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 267264
# Layer block3.5.conv1_1x1:
#   W: torch.Size([256, 1024, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([1024, 4])
#   Parameters: 267264
# Layer block3.5.conv2_3x3:
#   W: torch.Size([256, 256, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 256])
#   Lora_B: torch.Size([2304, 4])
#   Parameters: 600064
# Layer block3.5.conv3_1x1:
#   W: torch.Size([1024, 256, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 1024])
#   Lora_B: torch.Size([256, 4])
#   Parameters: 267264
# Layer block4.0.projection.0:
#   W: torch.Size([2048, 1024, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 2048])
#   Lora_B: torch.Size([1024, 4])
#   Parameters: 2109440
# Layer block4.0.conv1_1x1:
#   W: torch.Size([512, 1024, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([1024, 4])
#   Parameters: 530432
# Layer block4.0.conv2_3x3:
#   W: torch.Size([512, 512, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([4608, 4])
#   Parameters: 2379776
# Layer block4.0.conv3_1x1:
#   W: torch.Size([2048, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 2048])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 1058816
# Layer block4.1.conv1_1x1:
#   W: torch.Size([512, 2048, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([2048, 4])
#   Parameters: 1058816
# Layer block4.1.conv2_3x3:
#   W: torch.Size([512, 512, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([4608, 4])
#   Parameters: 2379776
# Layer block4.1.conv3_1x1:
#   W: torch.Size([2048, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 2048])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 1058816
# Layer block4.2.conv1_1x1:
#   W: torch.Size([512, 2048, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([2048, 4])
#   Parameters: 1058816
# Layer block4.2.conv2_3x3:
#   W: torch.Size([512, 512, 3, 3])
#   B: No bias
#   Lora_A: torch.Size([4, 512])
#   Lora_B: torch.Size([4608, 4])
#   Parameters: 2379776
# Layer block4.2.conv3_1x1:
#   W: torch.Size([2048, 512, 1, 1])
#   B: No bias
#   Lora_A: torch.Size([4, 2048])
#   Lora_B: torch.Size([512, 4])
#   Parameters: 1058816
# Layer fc1:
#   W: torch.Size([10, 2048])
#   B: torch.Size([10])
#   Lora_A: torch.Size([4, 2048])
#   Lora_B: torch.Size([10, 4])
#   Parameters: 28722
#
# Total number of parameters (original): 23,469,130
# Total number of parameters (original + LoRA): 23,794,742
# Parameters introduced by LoRA: 325,612
# Parameters increment: 1.387%

# %%
def train(train_loader , model , epochs=1 , total_iterations_limit = None):

        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay = 0.005, momentum = 0.9)  


        # Train the model
        total_step = len(train_loader)

        total_step = len(train_loader)

        for epoch in range(num_epochs):
            for i, (images, labels) in enumerate(train_loader):  
                # Move tensors to the configured device
                images = images.to(device)
                labels = labels.to(device)
                
                # Forward pass
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                        .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
                    
            # Validation
            with torch.no_grad():
                correct = 0
                total = 0
                for images, labels in test_loader:
                    images = images.to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                    del images, labels, outputs
            
                print('Accuracy of the network on the {} validation images: {} %'.format(5000, 100 * correct / total))

# %% [markdown]
# # Now lets fine tune it on 6,3,8

# %%
for name, param in model.named_parameters():
    if 'lora' not in name:
        print(f'Freezing non-LoRA parameter {name}')
        param.requires_grad = False

# Load the MNIST dataset again, by keeping only the digit 9
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

# Create a dataloader for the training
include_indices = (mnist_trainset.targets == 6) | (mnist_trainset.targets == 3) | (mnist_trainset.targets == 8)

# Apply the mask to both data and targets
mnist_trainset.data = mnist_trainset.data[include_indices]
mnist_trainset.targets = mnist_trainset.targets[include_indices]
train_loader = torch.utils.data.DataLoader(mnist_trainset, batch_size=10, shuffle=True)

# Train the network with LoRA only on the digit 9 and only for 100 batches (hoping that it would improve the performance on the digit 9)
train(train_loader, model, epochs=1, total_iterations_limit=100)
# Out:
# Freezing non-LoRA parameter conv1.parametrizations.weight.original
# Freezing non-LoRA parameter batchnorm1.weight
# Freezing non-LoRA parameter batchnorm1.bias
# Freezing non-LoRA parameter block1.0.projection.0.parametrizations.weight.original
# Freezing non-LoRA parameter block1.0.projection.1.weight
# Freezing non-LoRA parameter block1.0.projection.1.bias
# Freezing non-LoRA parameter block1.0.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block1.0.batchnorm1.weight
# Freezing non-LoRA parameter block1.0.batchnorm1.bias
# Freezing non-LoRA parameter block1.0.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block1.0.batchnorm2.weight
# Freezing non-LoRA parameter block1.0.batchnorm2.bias
# Freezing non-LoRA parameter block1.0.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block1.0.batchnorm3.weight
# Freezing non-LoRA parameter block1.0.batchnorm3.bias
# Freezing non-LoRA parameter block1.1.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block1.1.batchnorm1.weight
# Freezing non-LoRA parameter block1.1.batchnorm1.bias
# Freezing non-LoRA parameter block1.1.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block1.1.batchnorm2.weight
# Freezing non-LoRA parameter block1.1.batchnorm2.bias
# Freezing non-LoRA parameter block1.1.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block1.1.batchnorm3.weight
# Freezing non-LoRA parameter block1.1.batchnorm3.bias
# Freezing non-LoRA parameter block1.2.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block1.2.batchnorm1.weight
# Freezing non-LoRA parameter block1.2.batchnorm1.bias
# Freezing non-LoRA parameter block1.2.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block1.2.batchnorm2.weight
# Freezing non-LoRA parameter block1.2.batchnorm2.bias
# Freezing non-LoRA parameter block1.2.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block1.2.batchnorm3.weight
# Freezing non-LoRA parameter block1.2.batchnorm3.bias
# Freezing non-LoRA parameter block2.0.projection.0.parametrizations.weight.original
# Freezing non-LoRA parameter block2.0.projection.1.weight
# Freezing non-LoRA parameter block2.0.projection.1.bias
# Freezing non-LoRA parameter block2.0.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.0.batchnorm1.weight
# Freezing non-LoRA parameter block2.0.batchnorm1.bias
# Freezing non-LoRA parameter block2.0.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block2.0.batchnorm2.weight
# Freezing non-LoRA parameter block2.0.batchnorm2.bias
# Freezing non-LoRA parameter block2.0.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.0.batchnorm3.weight
# Freezing non-LoRA parameter block2.0.batchnorm3.bias
# Freezing non-LoRA parameter block2.1.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.1.batchnorm1.weight
# Freezing non-LoRA parameter block2.1.batchnorm1.bias
# Freezing non-LoRA parameter block2.1.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block2.1.batchnorm2.weight
# Freezing non-LoRA parameter block2.1.batchnorm2.bias
# Freezing non-LoRA parameter block2.1.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.1.batchnorm3.weight
# Freezing non-LoRA parameter block2.1.batchnorm3.bias
# Freezing non-LoRA parameter block2.2.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.2.batchnorm1.weight
# Freezing non-LoRA parameter block2.2.batchnorm1.bias
# Freezing non-LoRA parameter block2.2.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block2.2.batchnorm2.weight
# Freezing non-LoRA parameter block2.2.batchnorm2.bias
# Freezing non-LoRA parameter block2.2.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.2.batchnorm3.weight
# Freezing non-LoRA parameter block2.2.batchnorm3.bias
# Freezing non-LoRA parameter block2.3.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.3.batchnorm1.weight
# Freezing non-LoRA parameter block2.3.batchnorm1.bias
# Freezing non-LoRA parameter block2.3.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block2.3.batchnorm2.weight
# Freezing non-LoRA parameter block2.3.batchnorm2.bias
# Freezing non-LoRA parameter block2.3.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block2.3.batchnorm3.weight
# Freezing non-LoRA parameter block2.3.batchnorm3.bias
# Freezing non-LoRA parameter block3.0.projection.0.parametrizations.weight.original
# Freezing non-LoRA parameter block3.0.projection.1.weight
# Freezing non-LoRA parameter block3.0.projection.1.bias
# Freezing non-LoRA parameter block3.0.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.0.batchnorm1.weight
# Freezing non-LoRA parameter block3.0.batchnorm1.bias
# Freezing non-LoRA parameter block3.0.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block3.0.batchnorm2.weight
# Freezing non-LoRA parameter block3.0.batchnorm2.bias
# Freezing non-LoRA parameter block3.0.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.0.batchnorm3.weight
# Freezing non-LoRA parameter block3.0.batchnorm3.bias
# Freezing non-LoRA parameter block3.1.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.1.batchnorm1.weight
# Freezing non-LoRA parameter block3.1.batchnorm1.bias
# Freezing non-LoRA parameter block3.1.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block3.1.batchnorm2.weight
# Freezing non-LoRA parameter block3.1.batchnorm2.bias
# Freezing non-LoRA parameter block3.1.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.1.batchnorm3.weight
# Freezing non-LoRA parameter block3.1.batchnorm3.bias
# Freezing non-LoRA parameter block3.2.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.2.batchnorm1.weight
# Freezing non-LoRA parameter block3.2.batchnorm1.bias
# Freezing non-LoRA parameter block3.2.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block3.2.batchnorm2.weight
# Freezing non-LoRA parameter block3.2.batchnorm2.bias
# Freezing non-LoRA parameter block3.2.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.2.batchnorm3.weight
# Freezing non-LoRA parameter block3.2.batchnorm3.bias
# Freezing non-LoRA parameter block3.3.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.3.batchnorm1.weight
# Freezing non-LoRA parameter block3.3.batchnorm1.bias
# Freezing non-LoRA parameter block3.3.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block3.3.batchnorm2.weight
# Freezing non-LoRA parameter block3.3.batchnorm2.bias
# Freezing non-LoRA parameter block3.3.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.3.batchnorm3.weight
# Freezing non-LoRA parameter block3.3.batchnorm3.bias
# Freezing non-LoRA parameter block3.4.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.4.batchnorm1.weight
# Freezing non-LoRA parameter block3.4.batchnorm1.bias
# Freezing non-LoRA parameter block3.4.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block3.4.batchnorm2.weight
# Freezing non-LoRA parameter block3.4.batchnorm2.bias
# Freezing non-LoRA parameter block3.4.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.4.batchnorm3.weight
# Freezing non-LoRA parameter block3.4.batchnorm3.bias
# Freezing non-LoRA parameter block3.5.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.5.batchnorm1.weight
# Freezing non-LoRA parameter block3.5.batchnorm1.bias
# Freezing non-LoRA parameter block3.5.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block3.5.batchnorm2.weight
# Freezing non-LoRA parameter block3.5.batchnorm2.bias
# Freezing non-LoRA parameter block3.5.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block3.5.batchnorm3.weight
# Freezing non-LoRA parameter block3.5.batchnorm3.bias
# Freezing non-LoRA parameter block4.0.projection.0.parametrizations.weight.original
# Freezing non-LoRA parameter block4.0.projection.1.weight
# Freezing non-LoRA parameter block4.0.projection.1.bias
# Freezing non-LoRA parameter block4.0.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block4.0.batchnorm1.weight
# Freezing non-LoRA parameter block4.0.batchnorm1.bias
# Freezing non-LoRA parameter block4.0.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block4.0.batchnorm2.weight
# Freezing non-LoRA parameter block4.0.batchnorm2.bias
# Freezing non-LoRA parameter block4.0.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block4.0.batchnorm3.weight
# Freezing non-LoRA parameter block4.0.batchnorm3.bias
# Freezing non-LoRA parameter block4.1.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block4.1.batchnorm1.weight
# Freezing non-LoRA parameter block4.1.batchnorm1.bias
# Freezing non-LoRA parameter block4.1.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block4.1.batchnorm2.weight
# Freezing non-LoRA parameter block4.1.batchnorm2.bias
# Freezing non-LoRA parameter block4.1.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block4.1.batchnorm3.weight
# Freezing non-LoRA parameter block4.1.batchnorm3.bias
# Freezing non-LoRA parameter block4.2.conv1_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block4.2.batchnorm1.weight
# Freezing non-LoRA parameter block4.2.batchnorm1.bias
# Freezing non-LoRA parameter block4.2.conv2_3x3.parametrizations.weight.original
# Freezing non-LoRA parameter block4.2.batchnorm2.weight
# Freezing non-LoRA parameter block4.2.batchnorm2.bias
# Freezing non-LoRA parameter block4.2.conv3_1x1.parametrizations.weight.original
# Freezing non-LoRA parameter block4.2.batchnorm3.weight
# Freezing non-LoRA parameter block4.2.batchnorm3.bias
# Freezing non-LoRA parameter fc1.bias
# Freezing non-LoRA parameter fc1.parametrizations.weight.original
# Epoch [1/1], Step [1790/1790], Loss: 0.0054
# Accuracy of the network on the 5000 validation images: 61.88 %

# %%
enable_disable_lora(model,enabled=True)
test()
# Out:
# Testing: 100%|██████████| 1000/1000 [00:09<00:00, 106.60it/s]
# Accuracy : 0.619
# wrong counts for the digit 0 : 99
# wrong counts for the digit 1 : 845
# wrong counts for the digit 2 : 881
# wrong counts for the digit 3 : 4
# wrong counts for the digit 4 : 537
# wrong counts for the digit 5 : 305
# wrong counts for the digit 6 : 7
# wrong counts for the digit 7 : 567
# wrong counts for the digit 8 : 25
# wrong counts for the digit 9 : 542

# %%
enable_disable_lora(model,enabled=False)
test()
# Out:
# Testing: 100%|██████████| 1000/1000 [00:06<00:00, 151.48it/s]
# Accuracy : 0.943
# wrong counts for the digit 0 : 21
# wrong counts for the digit 1 : 10
# wrong counts for the digit 2 : 73
# wrong counts for the digit 3 : 143
# wrong counts for the digit 4 : 34
# wrong counts for the digit 5 : 25
# wrong counts for the digit 6 : 36
# wrong counts for the digit 7 : 69
# wrong counts for the digit 8 : 70
# wrong counts for the digit 9 : 93

# %% [markdown]
# # Thats it folks
